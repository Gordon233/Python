# %%
import requests

from selenium.webdriver import Chrome
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.options import Options #Don't show web page window
import time
from bs4 import BeautifulSoup



#不显示浏览器使用的过程
opt = Options()
opt.add_argument('--headless')
opt.add_argument('--disable-gpu')
opt.add_argument('start-maximized')
#-------------------------------------
web = Chrome(options=opt,executable_path='./chromedriver')
web.maximize_window()
url = "https://wallstreetcn.com/live/us-stock"


web.get(url)
time.sleep(5)
text = web.page_source
soup=BeautifulSoup(text,"html.parser")
news_list=soup.select('p')



for i in news_list:
    print(i.get_text())
    print(' ')


web.quit()
# Out:
# /var/folders/8c/jsk78s0s0nv4fp2cz0bph24m0000gn/T/ipykernel_27609/1422703196.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   web = Chrome(options=opt,executable_path='./chromedriver')
# 免疫医学平台Adaptive生物技术（ADPT）上涨13.8%，至少创11月30日以来最大盘中涨幅，刷新日高至8.08美元。Piper Sandler分析师 David Westenberg上调该公司评级至超配（之前持中性评级），对该公司2023年微小残留病（MRD）业务的前景看法乐观。
#
# 德国财长Lindner：希望（欧美/德国与美国）“友好相处”，以避免美国挑起贸易战。
#
# 呼吁拜登政府在近期推出的绿色补贴计划方面遵守“友好相处”的原则，拜登的相关法案存在触发欧美贸易战的威胁。
#
# 美股行业ETF周三盘初多数上涨，银行业ETF涨超1.6%领跑，区域银行ETF、能源业ETF、金融业ETF、全球航空业ETF、可选消费ETF也涨超1.0%，生物科技指数ETF则跌将近0.2%，网络股指数ETF跌超0.5%。
#
# 纳斯达克金龙中国指数美股盘初窄幅震荡，目前跌0.2%。成分股多尼斯跌4.3%表现最差，晶科能源和趣店跌超3%，微米、新氧、逸仙电商、小鹏汽车等跌2%，陆金所则涨超1.0%，小牛电动涨1.9%。
#
# 联邦快递（FDX）高开6.4%，创6月份以来最大盘中涨幅。
#
# 耐克（NKE）高开13%，创2021年6月份以来最大盘中涨幅。
#
# 标普500指数高开17.87点，涨幅0.47%，报3839.49点；
#
# 道琼斯工业平均指数高开178.35点，涨幅0.54%，报33028.09点；
#
# 纳斯达克综合指数高开44.89点，涨幅0.43%，报10592.00点。
#
# 欧盟糖市参考价较11月份上涨14%，至586欧元/吨。
#
# 数字货币交易所Coinbase被（欧元区）爱尔兰央行批准为VASP。
#
# ...
